# %% [markdown]
# ## Churn Prediction with PySpark using MLlib and ML Packages

# %%
# Check version of python

import sys
print(sys.version)
# Out:
# 2.7.11 |Anaconda 4.0.0 (64-bit)| (default, Dec  6 2015, 18:08:32)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %%
# Source: https://www.mapr.com/blog/churn-prediction-pyspark-using-mllib-and-ml-packages

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#set Matplotlib inline plotting and load Pandas package
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'

# %%
from pyspark import SparkContext, SparkConf, HiveContext, Row

hive_ctx = HiveContext(sc)
hive_ctx.setConf("hive.exec.dynamic.partition", "true")
hive_ctx.setConf("hive.exec.dynamic.partition.mode", "nonstrict")
hive_ctx.setConf("hive.exec.max.dynamic.partitions", "10000")
hive_ctx.sql("SET spark.sql.parquet.compression.codec=snappy") 

hive_ctx.sql("use prod_dxbreach_metrics")
# Out:
# DataFrame[result: string]

# %%
# Load data 

Churn_data = hive_ctx.sql("Select * from bi_churnanalysistable")

# %%
# Look at the first 5 results

pd.DataFrame(Churn_data.take(5), columns=Churn_data.columns).transpose() 

# Same thing but without transpose (less easy to read)

 # pd.DataFrame(Churn_data.take(5), columns=Churn_data.columns)
# Out:
#                                       0                 1                  2  \
# s__uid                       Searinox23  2533274898020741  76561198291735656
# cohort                         48112016           3592016            3582016
# monthcohort                      112016             92016              82016
# nbsessions                            4                 2                  2
# days                                  3                 2                  2
# firstsessionduration                  0                 3                  0
# uniquemapsplayed                     24                 6                 11
# totalinfiltrations                   65                 7                 16
# avgattemptspermap                     3                 1                  1
# successes                            23                 5                 11
# abandons                              0                 0                  0
# deaths                                1                 0                  0
# timelimits                            0                 0                  0
# lockdowns                             2                 1                  0
# detections                            0                 0                  0
# retries                              36                 1                  4
# fails                                39                 2                  4
# successesfailsratio                   1                 3                  3
# lifespan                              2                 6                  1
# scchallenges                          1                 0                  1
# playerschallenges                     0                 0                  0
# challengesuccesses                    0                 0                  0
# totalcreditpackspurchased             0                 0                  0
# uniquecreditpackspurchased            0                 0                  0
# creditspent                           0                 0                  0
# totalchipsetpackspurchased            0                 0                  0
# uniquechipsetpackspurchased           0                 0                  0
# chipsetspent                          0                 0                  0
# abilityparts                          0                 0                  0
# weaponparts                        2040                 0                  0
# ischurned                             0                 1                  1
#
#                                        3           4
# s__uid                       ChadtheRad1  BOA-Player
# cohort                           3592016     3592016
# monthcohort                        92016       92016
# nbsessions                             3           2
# days                                   2           2
# firstsessionduration                   9          17
# uniquemapsplayed                       3          11
# totalinfiltrations                    11          25
# avgattemptspermap                      4           2
# successes                              8          10
# abandons                               0           0
# deaths                                 0           1
# timelimits                             0           0
# lockdowns                              0           0
# detections                             0           0
# retries                                3          13
# fails                                  3          14
# successesfailsratio                    3           1
# lifespan                               1           8
# scchallenges                           0           1
# playerschallenges                      0           0
# challengesuccesses                     0           0
# totalcreditpackspurchased              0           4
# uniquecreditpackspurchased             0           1
# creditspent                            0        6000
# totalchipsetpackspurchased             0           0
# uniquechipsetpackspurchased            0           0
# chipsetspent                           0           0
# abilityparts                           0           0
# weaponparts                            0         504
# ischurned                              1           1

# %% [markdown]
# ### Split between training and test

# %%
# Obtain the number of rows:
Churn_data.describe().toPandas().transpose()
# Out:
#                                  0                    1                   2  \
# summary                      count                 mean              stddev
# nbsessions                   56126    4.394148879307273   6.023382261709859
# days                         56126   3.1059402059651497   2.725114017059608
# firstsessionduration         56126    19.80123294017033  120.54168405837464
# uniquemapsplayed             56126    15.57247977764316   18.29411805736801
# totalinfiltrations           56126    52.47010298257492   124.5247622592761
# avgattemptspermap            56126             Infinity                 NaN
# successes                    56126   22.634732566012186   53.86495605182251
# abandons                     56126   0.9512525389302641   6.146451167141019
# deaths                       56126   2.7703916188575706  13.203019184171087
# timelimits                   56126  0.19493639311549016  0.8120934581796821
# lockdowns                    56126   1.0802301963439405   3.639735479328252
# detections                   56126   0.6780101913551652   2.290248525929923
# retries                      56126    22.64911092898122   62.59713073832188
# fails                        56126    28.32393186758365   76.56946184485675
# successesfailsratio          56126                  NaN                 NaN
# lifespan                     56126   15.025941631329509   103.4690584763695
# scchallenges                 56126   2.0442753803941134  12.691634110865834
# playerschallenges            56126  0.25152335815842924   5.961345784222823
# challengesuccesses           56126   0.5775041870078038   7.650942101660886
# totalcreditpackspurchased    56126    5.856038199764815   19.54771572328319
# uniquecreditpackspurchased   56126   0.8505505469835727  1.3450323879035573
# creditspent                  56126    10566.96539928019    72664.3787472101
# totalchipsetpackspurchased   56126  0.07335281331290311  0.6276055741155099
# uniquechipsetpackspurchased  56126  0.05238214018458468  0.3334905896932304
# chipsetspent                 56126   1.7149805794106119  14.742645469677816
# abilityparts                 56126   31187.386327192387   820936.4087163776
# weaponparts                  56126   11908.456544204113   344266.7934755591
#
#                                3         4
# summary                      min       max
# nbsessions                     2       327
# days                           2        85
# firstsessionduration           0     11714
# uniquemapsplayed               0        95
# totalinfiltrations             1      4997
# avgattemptspermap            1.0  Infinity
# successes                      0      2744
# abandons                       0       483
# deaths                         0      2023
# timelimits                     0        56
# lockdowns                      0       282
# detections                     0       161
# retries                        0      2868
# fails                          0      2931
# successesfailsratio          0.0       NaN
# lifespan                       0     17062
# scchallenges                   0       870
# playerschallenges              0       428
# challengesuccesses             0       680
# totalcreditpackspurchased      0       924
# uniquecreditpackspurchased     0         8
# creditspent                    0  10179000
# totalchipsetpackspurchased     0        38
# uniquechipsetpackspurchased    0        11
# chipsetspent                   0       908
# abilityparts                   0  88078725
# weaponparts                    0  52916300

# %%
# Create pandas df
Churn_data_Pandas = pd.DataFrame(Churn_data.take(56126), columns=Churn_data.columns) # take(total number of rows)

# Split the data
Churn_train = Churn_data_Pandas.sample(frac=0.8) 
Churn_test = Churn_data_Pandas.drop(Churn_train.index)

# %% [markdown]
# ## Summary Statistics

# %%
Churn_train.describe().transpose()
# Out:
#                                count          mean            std  min  25%  \
# nbsessions                   44901.0  4.396984e+00       6.120859  2.0  2.0
# days                         44901.0  3.106790e+00       2.740917  2.0  2.0
# firstsessionduration         44901.0  1.994140e+01     125.940742  0.0  0.0
# uniquemapsplayed             44901.0  1.556431e+01      18.268112  0.0  4.0
# totalinfiltrations           44901.0  5.249919e+01     124.443565  1.0  6.0
# avgattemptspermap            44901.0           inf            NaN  1.0  1.0
# successes                    44901.0  2.261513e+01      53.894625  0.0  4.0
# abandons                     44901.0  9.456360e-01       6.041173  0.0  0.0
# deaths                       44901.0  2.753480e+00      10.286963  0.0  0.0
# timelimits                   44901.0  1.971894e-01       0.831615  0.0  0.0
# lockdowns                    44901.0  1.082648e+00       3.520618  0.0  0.0
# detections                   44901.0  6.771787e-01       2.246659  0.0  0.0
# retries                      44901.0  2.271116e+01      62.737049  0.0  0.0
# fails                        44901.0  2.836730e+01      76.126869  0.0  1.0
# successesfailsratio          44256.0           inf            NaN  0.0  1.0
# lifespan                     44901.0  1.475678e+01      82.566858  0.0  2.0
# scchallenges                 44901.0  2.059019e+00      12.902770  0.0  0.0
# playerschallenges            44901.0  2.454511e-01       5.714589  0.0  0.0
# challengesuccesses           44901.0  5.719472e-01       7.540685  0.0  0.0
# totalcreditpackspurchased    44901.0  5.843300e+00      19.690309  0.0  0.0
# uniquecreditpackspurchased   44901.0  8.483553e-01       1.345110  0.0  0.0
# creditspent                  44901.0  1.059891e+04   75758.357534  0.0  0.0
# totalchipsetpackspurchased   44901.0  7.405180e-02       0.649838  0.0  0.0
# uniquechipsetpackspurchased  44901.0  5.184740e-02       0.330664  0.0  0.0
# chipsetspent                 44901.0  1.734728e+00      15.310166  0.0  0.0
# abilityparts                 44901.0  3.040403e+04  773878.221564  0.0  0.0
# weaponparts                  44901.0  1.106992e+04  273657.394250  0.0  0.0
#
#                               50%     75%           max
# nbsessions                    3.0     5.0  3.270000e+02
# days                          2.0     3.0  8.500000e+01
# firstsessionduration          0.0    20.0  1.171400e+04
# uniquemapsplayed              9.0    18.0  9.500000e+01
# totalinfiltrations           17.0    48.0  4.997000e+03
# avgattemptspermap             2.0     3.0           inf
# successes                    11.0    24.0  2.744000e+03
# abandons                      0.0     0.0  4.700000e+02
# deaths                        0.0     2.0  6.990000e+02
# timelimits                    0.0     0.0  5.600000e+01
# lockdowns                     0.0     1.0  2.310000e+02
# detections                    0.0     1.0  1.610000e+02
# retries                       4.0    18.0  2.663000e+03
# fails                         5.0    23.0  2.819000e+03
# successesfailsratio           2.0     5.0           inf
# lifespan                      7.0    18.0  1.703900e+04
# scchallenges                  0.0     1.0  8.700000e+02
# playerschallenges             0.0     0.0  4.280000e+02
# challengesuccesses            0.0     0.0  6.800000e+02
# totalcreditpackspurchased     0.0     3.0  9.240000e+02
# uniquecreditpackspurchased    0.0     1.0  8.000000e+00
# creditspent                   0.0  4000.0  1.017900e+07
# totalchipsetpackspurchased    0.0     0.0  3.800000e+01
# uniquechipsetpackspurchased   0.0     0.0  1.100000e+01
# chipsetspent                  0.0     0.0  9.080000e+02
# abilityparts                  0.0     0.0  7.955205e+07
# weaponparts                   0.0  1266.0  2.853686e+07

# %% [markdown]
# ## Correlations and Data Preparation

# %%
# Cast ischurned as int

Churn_train[['ischurned']] = Churn_train[['ischurned']].apply(pd.to_numeric)

# %%
# take a look at the different types of data in Churn_data

Churn_train.dtypes
# Out:
# s__uid                          object
# cohort                          object
# monthcohort                     object
# nbsessions                       int64
# days                             int64
# firstsessionduration             int64
# uniquemapsplayed                 int64
# totalinfiltrations               int64
# avgattemptspermap              float64
# successes                        int64
# abandons                         int64
# deaths                           int64
# timelimits                       int64
# lockdowns                        int64
# detections                       int64
# retries                          int64
# fails                            int64
# successesfailsratio            float64
# lifespan                         int64
# scchallenges                     int64
# playerschallenges                int64
# challengesuccesses               int64
# totalcreditpackspurchased        int64
# uniquecreditpackspurchased       int64
# creditspent                      int64
# totalchipsetpackspurchased       int64
# uniquechipsetpackspurchased      int64
# chipsetspent                     int64
# abilityparts                     int64
# weaponparts                      int64
# ischurned                        int64
# dtype: object

# %%
# Keep only int64 features

cols = list(Churn_train.ix[:,3:8] + Churn_train.ix[:,9:17] + Churn_train.ix[:,18:31]) 

# Select a 10% sample

Churn_train[cols].sample(frac=0.1).transpose()
# Out:
#                              18940  43589  6751   4263   30452  5774   39432  \
# abandons                         1      0      0      0      0      0      0
# abilityparts                     0      0      0      0      0      0      0
# challengesuccesses               0      0      0      0      0      0      0
# chipsetspent                     0      0      0      0      0      0      0
# creditspent                      0   2000      0  34000   5000      0   2500
# days                             6      4      2      3      2      2      2
# deaths                           4      0      0     10      1      0      2
# detections                       2      0      0      1      1      0      0
# fails                          179      3      0     46     20     11      7
# firstsessionduration             0     15      0     69      0      0      7
# ischurned                        1      0      1      1      0      1      1
# lifespan                         9     19      8     13      1      3      5
# lockdowns                        1      1      0      2      1      0      2
# nbsessions                      21      5      2      4      4      2      4
# playerschallenges                0      0      0      0      0      0      0
# retries                        171      2      0     33     17     11      1
# scchallenges                     1      0      0      1      1      0      0
# successes                       55      9      2     25      9     11      8
# timelimits                       0      0      0      0      0      0      2
# totalchipsetpackspurchased       0      0      0      0      0      0      0
# totalcreditpackspurchased        0      2      0     23      5      0      2
# totalinfiltrations             248     13      4     73     31     24     15
# uniquechipsetpackspurchased      0      0      0      0      0      0      0
# uniquecreditpackspurchased       0      1      0      3      1      0      2
# uniquemapsplayed                52     10      3     24     11     12      8
# weaponparts                   8209    110      0   2170      0      0     34
#
#                              1346   24913  22162  ...    48368  15110  26855  \
# abandons                         0      0      0  ...        0      0      0
# abilityparts                     0      0      0  ...        0      0      0
# challengesuccesses               0      0      0  ...        0      0      0
# chipsetspent                     0      0      0  ...        0      0      0
# creditspent                      0      0      0  ...     5500      0      0
# days                             2      2      2  ...        2      2      2
# deaths                           0      0      0  ...        1      5      0
# detections                       0      0      0  ...        0      2      0
# fails                            0      0      0  ...        6    140      0
# firstsessionduration             0      0      0  ...        0      0      0
# ischurned                        1      1      1  ...        1      1      1
# lifespan                         2      4      1  ...        2      1     23
# lockdowns                        0      0      0  ...        1      0      0
# nbsessions                       2      2      2  ...        2      5      2
# playerschallenges                0      0      0  ...        0      0      0
# retries                          0      0      0  ...        4    133      0
# scchallenges                     0      0      0  ...        1      2      0
# successes                        1      2      2  ...       25    120      1
# timelimits                       0      0      0  ...        0      0      0
# totalchipsetpackspurchased       0      0      0  ...        0      0      0
# totalcreditpackspurchased        0      0      0  ...        4      0      0
# totalinfiltrations               1      4      2  ...       33    264      2
# uniquechipsetpackspurchased      0      0      0  ...        0      0      0
# uniquecreditpackspurchased       0      0      0  ...        3      0      0
# uniquemapsplayed                 1      4      2  ...       21     18      1
# weaponparts                      0      0      0  ...     3422      0      0
#
#                              45792  14689  26668  11159  23027  45810  44597
# abandons                         0      4      0      0      0      1      2
# abilityparts                     0      0      0      0      0      0      0
# challengesuccesses               0      0      0      0      0      0      0
# chipsetspent                     0      0      0      0      0      0      0
# creditspent                      0   4500      0      0      0   6500   2000
# days                             2      3      2      2      2      8      3
# deaths                           0      1      0      0      0      1      0
# detections                       0      0      0      0      0      1      2
# fails                            3     36      2      0      5     73     74
# firstsessionduration             0     63     27      9     31      0      0
# ischurned                        1      1      1      1      1      0      1
# lifespan                         2      5      9      1     16     55      3
# lockdowns                        0      2      0      0      0      6      0
# nbsessions                       2      3      2      3      2     10      6
# playerschallenges                0      0      0      0      0      0      0
# retries                          3     29      2      0      5     63     70
# scchallenges                     0      1      0      0      0      0      0
# successes                        7     29     10      4      7     51     26
# timelimits                       0      0      0      0      0      1      0
# totalchipsetpackspurchased       0      0      0      0      0      0      0
# totalcreditpackspurchased        0      3      0      0      0      5      1
# totalinfiltrations              11     65     12      4     12    126    102
# uniquechipsetpackspurchased      0      0      0      0      0      0      0
# uniquecreditpackspurchased       0      1      0      0      0      2      1
# uniquemapsplayed                 8     16      9      4      7     50     28
# weaponparts                      0      0    350      0    350   4664    186
#
# [26 rows x 4490 columns]

# %%
# Keep only the numeric features

# numeric_features = [t[0] for t in Churn_train.dtypes if t[1] == 'int64' or t[1] == 'float64'] 

# sampled_data = Churn_train.select(numeric_features).sample(False, 0.10).toPandas()

# %%
# Matrix of covariance

sampled_data = Churn_train[cols].sample(frac=0.1) 

axs = pd.scatter_matrix(sampled_data, figsize=(12, 12)); # (18,18)?

# Rotate axis labels and remove axis ticks
n = len(sampled_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())

# %% [markdown]
# ### Alternative 1: Export to CSV and use R to determine which fields to drop (glm method)

# %%
# If on my computer: 
# pd.DataFrame.to_csv()
# import os
# path = 'C:\Users\mdeleseleuc\Documents'
# output_filename = 'Churn_train.csv'
# Churn_train.to_csv(os.path.join(path,output_filename))

# In the cluster:

Churn_train_Spark = sqlContext.createDataFrame(Churn_train) # Convert Panda df to Spark df

Churn_train_Spark.registerTempTable("mytempTableTrain") # Create temporary table 

# sqlContext.sql("drop table mytable")
sqlContext.sql("create table if not exists mytableTrain as select * from mytempTable") # create table in hive
# Out:
# DataFrame[]

# %% [markdown]
# ### Alternative 2: Drop useless fields by hand (don't do that...)

# %%
# Let's get rid of highly correlated variables

Churn_train = Churn_train.drop('lifespan').drop('daysincelastseen') \
             .drop('uniquemapcompleted').drop()

Churn_train.describe().transpose()

# %% [markdown]
# ### Alternative 3: Feature Selection using tree Classifier

# %%
# Source 1: http://scikit-learn.org/stable/modules/feature_selection.html
"""Source 2: https://kaggle2.blob.core.windows.net/forum-message-attachments/44681/1286/
kaggle_forest.py?sv=2012-02-12&se=2016-11-14T22%3A52%3A58Z&sr=b&sp=r&sig=vizTB90DrEljcgvjIGgVVkPowHxAs%2BKO%2BZmqCzf8lms%3D"""

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn import ensemble

feature_cols = [col for col in Churn_train.columns if col not in ['s__uid', 'ischurned']]

X_train = Churn_train[feature_cols]
y = Churn_train['ischurned']

X_train.shape
# Out:
# (44901, 29)

# %%
# Get rid of NaN values
from sklearn.preprocessing import Imputer 
X_train = Imputer().fit_transform(X_train)

clf = ensemble.RandomForestClassifier()
clf.fit(X_train, y)

# Print the features importance
clf.feature_importances_
# Out:
# array([ 0.43351776,  0.04264213,  0.00872871,  0.01323066,  0.00788935,
#         0.02667869,  0.01354551,  0.01436285,  0.00357317,  0.00422756,
#         0.00191759,  0.00503151,  0.00282198,  0.00723792,  0.00738887,
#         0.37429109,  0.00359469,  0.00426691,  0.00175627,  0.00426762,
#         0.00274032,  0.00472647,  0.00057156,  0.00096561,  0.00095389,
#         0.00145347,  0.00761782])

# %%
# Take a look at the new shape

model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X_train)
X_new.shape
# Out:
# (44901, 3)

# %%
# Build a forest and compute the feature importances

# Source: http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html
          #sphx-glr-auto-examples-ensemble-plot-forest-importances-py

import numpy as np

importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
    
# Three informative features = Retries, abandons and abilityparts (86% of the variance)
# Out:
# Feature ranking:
# 1. feature 15 (0.373858)
# 2. feature 0 (0.291313)
# 3. feature 1 (0.201027)
# 4. feature 5 (0.022639)
# 5. feature 2 (0.010467)
# 6. feature 6 (0.010450)
# 7. feature 3 (0.010180)
# 8. feature 7 (0.009962)
# 9. feature 13 (0.009545)
# 10. feature 4 (0.007979)
# 11. feature 14 (0.007879)
# 12. feature 26 (0.006703)
# 13. feature 21 (0.004409)
# 14. feature 8 (0.004124)
# 15. feature 16 (0.003927)
# 16. feature 19 (0.003878)
# 17. feature 11 (0.003800)
# 18. feature 9 (0.003777)
# 19. feature 17 (0.002339)
# 20. feature 12 (0.002259)
# 21. feature 20 (0.002250)
# 22. feature 10 (0.002095)
# 23. feature 25 (0.001485)
# 24. feature 18 (0.001251)
# 25. feature 23 (0.001201)
# 26. feature 24 (0.000641)
# 27. feature 22 (0.000561)

# %% [markdown]
# ### Reprocessing: Normalize the features

# %% [markdown]
# Source
#
# http://machinelearningmastery.com/rescaling-data-for-machine-learning-in-python-with-scikit-learn/

# %% [markdown]
# ## Using the Spark MLlib Package
